# %% [markdown]
# # Stock Price Predictor

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import datetime as dt
import urllib.request, json
import os
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from operator import itemgetter
from sklearn.metrics import mean_squared_error
from math import sqrt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.optimizers import Adam

# %%
def summarize_diagnostics(history):
    ''' 
    Function that takes in the history object that model.fit() throws out,
    and unpacks it to plot the Cross Entropy Loss and Accuracy of the model
    Useful to compare the Training and Validation Set
    '''
    # plot loss
    plt.subplot(211)
    #plt.ylim(0, .025)
    plt.title('Cross Entropy Loss')
    plt.plot(history.history['loss'], color='blue', label='Training Set')
    #plt.plot(history.history['val_loss'], color='orange', label='Validation Set')
    plt.xlabel('Epoch')
    plt.ylabel('Loss Value')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
os.getcwd()
# Out:
# '/Users/aryamevada/Documents/Other Docs/Fun Side Projects/stocks_scraper/Stock-Price-Predicter'

# %%
df = pd.read_csv(os.path.join(os.getcwd(), 'data', 'aapl.us.txt'),delimiter=',',usecols=['Date','Open','High','Low','Close'])
df.head()
# Out:
#          Date     Open     High      Low    Close
# 0  1984-09-07  0.42388  0.42902  0.41874  0.42388
# 1  1984-09-10  0.42388  0.42516  0.41366  0.42134
# 2  1984-09-11  0.42516  0.43668  0.42516  0.42902
# 3  1984-09-12  0.42902  0.43157  0.41618  0.41618
# 4  1984-09-13  0.43927  0.44052  0.43927  0.43927

# %%
plt.figure(figsize=(18, 9))
sns.lineplot(range(df.shape[0]), (df['Low'] + df['High']) / 2.0)
plt.xticks(range(0, df.shape[0], 1000), df['Date'].loc[::1000], rotation=45)
plt.xlabel('Date',fontsize=14)
plt.ylabel('Mid Price',fontsize=14)
plt.show()

# %%
# Getting a midtrpiaces in an array
high = np.array(list(df.loc[:, 'High']))
low = np.array(list(df.loc[:, 'Low']))
mid = (high + low) / 2
print(2 * len(mid) / 3)
# Out:
# 5576.0

# %%
train_data = mid[:5576]
test_data = mid[5576:]

# %%
scaler = MinMaxScaler()
train_data = train_data.reshape(-1, 1)
print(train_data.shape)
test_data = test_data.reshape(-1, 1)
print(test_data.shape)
# Out:
# (5576, 1)
# (2788, 1)

# %%
EMA = 0.0
gamma = 0.1
for t in range(5576):
    EMA = gamma * train_data[t] + (1 - gamma) * EMA
    train_data[t] = EMA

# Used for visualization and test purposes
all_mid = np.concatenate([train_data,test_data], axis=0)

# %%
window = 250
N = train_data.size
std_avg_pred = []
std_avg_x = []
mse_errors = []

for pred in range(window, N):
    if pred >= N:
        date = dt.datetime.strptime(k, '%Y-%m-%d').date() + dt.timedelta(days=1)
    else:
        date = df.loc[pred, 'Date']
    
    # Add the training data for the date?
    std_avg_pred.append(np.mean(train_data[pred - window : pred]))
    # MSE adding
    mse_errors.append((std_avg_pred[-1] - train_data[pred])**2)
    # Add the dates
    std_avg_x.append(date)

print('MSE error for standard averaging: %.8f'%(0.5 * np.mean(mse_errors)))
# Out:
# MSE error for standard averaging: 0.26537449

# %%
plt.figure(figsize = (18,9))
plt.plot(range(df.shape[0]), all_mid, color='b',label='True')
plt.plot(range(window, N),std_avg_pred, color='orange',label='Prediction')
#plt.xticks(range(0,df.shape[0],50),df['Date'].loc[::50],rotation=45)
plt.xlabel('Date')
plt.ylabel('Mid Price')
plt.legend(fontsize=18)
plt.show()

# %%
data = df.sort_index(ascending=True, axis=0)
data.head()
print(len(data))
# Out:
# 8364

# %%
#setting index
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
for i in range(0, len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]

new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)
new_data.head()
# Out:
#               Close
# Date
# 1984-09-07  0.42388
# 1984-09-10  0.42134
# 1984-09-11  0.42902
# 1984-09-12  0.41618
# 1984-09-13  0.43927

# %%
dataset = new_data.values
train = dataset[:-1848]
test = dataset[-1848:]
len(test)
# Out:
# 1848

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(dataset)

# %%
x_train = []
y_train = []
for i in range(60, len(train)):
    x_train.append(scaled[i - 60: i, 0])
    y_train.append(scaled[i, 0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# Create the LSTM Model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=1, batch_size=1)
# Out:
# 6456/6456 [==============================] - 123s 19ms/step - loss: 3.0381e-05

# %%
inputs = new_data[len(new_data) - len(test) - 60:].values
inputs = inputs.reshape(-1, 1)
inputs  = scaler.transform(inputs)

# %%
x_test = []
for i in range(60, inputs.shape[0]):
    x_test.append(inputs[i - 60: i, 0])
x_test = np.array(x_test)

# %%
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
closing_price = model.predict(x_test)
closing_price = scaler.inverse_transform(closing_price)

# %%
train = new_data[:-1848]
test = new_data[-1848:]
test['Predictions'] = closing_price
test
# Out:
# <ipython-input-21-8220324f2e6c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = closing_price
#              Close  Predictions
# Date
# 2010-07-14  32.365    34.090599
# 2010-07-15    32.2    33.933685
# 2010-07-16  32.004    33.756657
# 2010-07-19  31.449    33.566471
# 2010-07-20   32.26    33.280029
# ...            ...          ...
# 2017-11-06  173.63   173.582108
# 2017-11-07  174.18   175.442963
# 2017-11-08  175.61   176.956955
# 2017-11-09  175.25   178.330078
# 2017-11-10  174.67   179.156631
#
# [1848 rows x 2 columns]

# %%
test.plot(figsize=(18, 9))

# %%
idx = pd.date_range('2017-11-11', periods=1200, freq='D')
forward = pd.Series(range(len(idx)), index=idx)
forward = pd.DataFrame(forward)
forward.drop(0, axis=1, inplace=True)

# %%
f_inputs = test.values
f_inputs = f_inputs.reshape(-1, 1)
f_inputs = scaler.transform(f_inputs)
print(f_inputs.shape)
# Out:
# (3696, 1)

# %%
f_test = []
for i in range(f_inputs.shape[0] - 1200, f_inputs.shape[0]):
    f_test.append(f_inputs[i - 100: i, 0])
f_test = np.array(f_test)
f_test.shape
# Out:
# (1200, 100)

# %%
f_test = np.reshape(f_test, (f_test.shape[0], f_test.shape[1], 1))
closing_price = model.predict(f_test)
closing_price = scaler.inverse_transform(closing_price)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 60, 1) for input Tensor("lstm_input:0", shape=(None, 60, 1), dtype=float32), but it was called on an input with incompatible shape (None, 100, 1).

# %%
forward["Apple Price Prediction"] = closing_price / 4

# %%
apple_curr = pd.read_csv(os.path.join(os.getcwd(), 'data', 'AAPL-2.csv'))

# %%
test1 = pd.DataFrame(forward["Apple Price Prediction"][:781])
apple_close = np.array(apple_curr['Close']).astype(float)
test1['Real Apple Price'] = apple_close
test1
# Out:
#             Apple Price Prediction  Real Apple Price
# 2017-11-11               32.604149         43.492500
# 2017-11-12               32.244797         42.834999
# 2017-11-13               32.421337         42.270000
# 2017-11-14               32.169365         42.775002
# 2017-11-15               32.342438         42.537498
# ...                            ...               ...
# 2019-12-27               31.140028        121.779999
# 2019-12-28               31.105711        127.879997
# 2019-12-29               31.291283        127.809998
# 2019-12-30               31.184721        128.699997
# 2019-12-31               31.373230        126.660004
#
# [781 rows x 2 columns]

# %%
test1.plot(figsize=(18, 9))

# %%
model.save('ltsm_model1')
# Out:
# WARNING:tensorflow:From /Users/aryamevada/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/aryamevada/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ltsm_model1/assets

# %% [markdown]
# ## Forward Prediciting with Current Data

# %%
curr_data2 = pd.read_csv(os.path.join(os.getcwd(), 'data', 'AAPL-3.csv'))
print(len(curr_data))
curr_data2
# Out:
# 10092
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.101087
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095813
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088780
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090978
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.093615
# ...           ...         ...         ...         ...         ...         ...
# 10087  2020-12-14  122.599998  123.349998  121.540001  121.779999  121.779999
# 10088  2020-12-15  124.339996  127.900002  124.129997  127.879997  127.879997
# 10089  2020-12-16  127.410004  128.369995  126.559998  127.809998  127.809998
# 10090  2020-12-17  128.899994  129.580002  128.039993  128.699997  128.699997
# 10091  2020-12-18  128.960007  129.100006  126.120003  126.660004  126.660004
#
#             Volume
# ...

# %%
# Get Closing Data
cleaned_data = pd.DataFrame(index=range(0,len(curr_data2)),columns=['Date', 'Close'])
for i in range(0, len(curr_data2)):
    cleaned_data['Date'][i] = curr_data2['Date'][i]
    cleaned_data['Close'][i] = curr_data2['Close'][i]

cleaned_data.index = cleaned_data.Date
cleaned_data.drop('Date', axis=1, inplace=True)
cleaned_data.dropna()
cleaned_data
# Out:
#                Close
# Date
# 1980-12-12  0.128348
# 1980-12-15  0.121652
# 1980-12-16  0.112723
# 1980-12-17  0.115513
# 1980-12-18  0.118862
# ...              ...
# 2020-12-14    121.78
# 2020-12-15    127.88
# 2020-12-16    127.81
# 2020-12-17     128.7
# 2020-12-18    126.66
#
# [10092 rows x 1 columns]

# %%
vals = cleaned_data.values
train2 = np.array(vals[:8000])
test2 = vals[8000:]

# %%
scaler2 = MinMaxScaler(feature_range=(0, 1))
scaled2 = scaler.fit_transform(vals)

# %%
x_train2 = []
y_train2 = []
for i in range(60, len(train2)):
    x_train2.append(scaled2[i - 60: i, 0])
    y_train2.append(scaled2[i, 0])
x_train2, y_train2 = np.array(x_train2), np.array(y_train2)
shape1 = x_train2.shape
x_train2 = x_train2[~np.isnan(x_train2)]
y_train2 = y_train2[~np.isnan(y_train2)]

x_train2 = np.reshape(x_train2, (shape1[0] - 1, shape1[1], 1))

# %%
np.any(np.isnan(y_train2))
# Out:
# False

# %%
# Create the LSTM Model
model2 = Sequential()
model2.add(LSTM(units=50, return_sequences=True, input_shape=(x_train2.shape[1], 1)))
model2.add(LSTM(units=50))
model2.add(Dense(1))

model2.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001))
history = model2.fit(x_train2, y_train2, epochs=2, batch_size=1)
# Out:
# Epoch 1/2
# 7939/7939 [==============================] - 148s 19ms/step - loss: 2.4447e-05
# Epoch 2/2
# 7939/7939 [==============================] - 146s 18ms/step - loss: 4.1432e-06

# %%
summarize_diagnostics(history)

# %%
inputs2 = cleaned_data[len(cleaned_data) - len(test) - 60:].values
inputs2 = inputs2.reshape(-1, 1)
inputs2  = scaler.transform(inputs2)

# %%
x_test2 = []
for i in range(60, inputs2.shape[0]):
    x_test2.append(inputs2[i - 60: i, 0])
x_test2 = np.array(x_test2)
print(x_test2.shape)
# Out:
# (364, 60)

# %%
x_test2 = np.reshape(x_test2, (x_test2.shape[0], x_test2.shape[1], 1))
closing_price2 = model.predict(x_test2)
closing_price2 = scaler.inverse_transform(closing_price2)

# %%
train = cleaned_data[:8000]
test2 = cleaned_data[-364:]
test2['Predictions'] = closing_price2
test2
# Out:
# <ipython-input-148-d29f08f2873f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test2['Predictions'] = closing_price2
#               Close  Predictions
# Date
# 2019-07-15  51.3025    52.693649
# 2019-07-16   51.125    52.907459
# 2019-07-17  50.8375    53.066093
# 2019-07-18   51.415    53.092209
# 2019-07-19  50.6475    53.222569
# ...             ...          ...
# 2020-12-14   121.78   127.076759
# 2020-12-15   127.88   126.723175
# 2020-12-16   127.81   128.113358
# 2020-12-17    128.7   129.545197
# 2020-12-18   126.66   130.870728
#
# [364 rows x 2 columns]

# %%
test2.plot(figsize=(18, 9))

# %%
idx = pd.date_range('2020-12-18', periods=365, freq='D')
forward2 = pd.Series(range(len(idx)), index=idx)
forward2 = pd.DataFrame(forward2)
forward2.drop(0, axis=1, inplace=True)
print(len(forward2))
forward2
# Out:
# 365
# Empty DataFrame
# Columns: []
# ...

# %%
f_inputs2 = test2.values
f_inputs2 = f_inputs2.reshape(-1, 1)
f_inputs2 = scaler.transform(f_inputs2)
f_inputs2.shape
# Out:
# (728, 1)

# %%
f_test2 = []
for i in range(f_inputs2.shape[0] - 365, f_inputs2.shape[0]):
    f_test2.append(f_inputs2[i - 60: i, 0])
f_test2 = np.array(f_test2)
f_test2.shape
# Out:
# (365, 60)

# %%
f_test2 = np.reshape(f_test2, (f_test2.shape[0], f_test2.shape[1], 1))
closing_price3 = model2.predict(f_test2)
closing_price3 = scaler.inverse_transform(closing_price3)
closing_price3.shape
# Out:
# (365, 1)

# %%
plt.figsize=(18, 9)
plt.plot(price_pred)

# %%
forward2['Prediction'] = closing_price3 + 40

# %%
forward2.plot(figsize=(12, 9))

# %%
model2.save(os.path.join(os.getcwd(), 'models, lstm_model2'))
# Out:
# INFO:tensorflow:Assets written to: /Users/aryamevada/Documents/Other Docs/Fun Side Projects/stocks_scraper/Stock-Price-Predicter/models, lstm_model2/assets
